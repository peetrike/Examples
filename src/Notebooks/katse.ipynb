# %% [markdown]
# # Polyglot ja PowerShell
#
# katsetame siin asju

# %%
Write-Output 'tere'

# %% [markdown]
# veel natuke asju

# %%
Test-NetConnection kapp.estpak.ee -port 443 | Out-Host
# Out:
# ComputerName     : kapp.estpak.ee
# RemoteAddress    : 194.126.106.131
# RemotePort       : 443
# InterfaceAlias   : Wi-Fi
# SourceAddress    : 10.65.56.71
# TcpTestSucceeded : True
# kapp.estpak.ee : This operation returned because the timeout period expired.
